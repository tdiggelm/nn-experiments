# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p /content/drive/My\ Drive/nn_output
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
OUTPUTDIR='/content/drive/My Drive/nn_output'

# %%
# !pip install keras-TCN

from keras.layers import (Bidirectional, Dense, Embedding, Input, Lambda, InputLayer, Reshape
                          , LSTM, RepeatVector, TimeDistributed, Flatten)
from keras.models import Model, Sequential, load_model
from tcn import TCN
from keras.utils import to_categorical
from keras import optimizers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.initializers import Constant
import numpy as np
from nltk.corpus import reuters
from itertools import chain
import nltk
nltk.download('reuters')
nltk.download('punkt')
from keras.callbacks import ModelCheckpoint
import os.path
import glob

USE_GLOVE = True
MAX_SEQUENCE_LEN = 100
MAX_NUM_WORDS = 10000
# Out:
# Requirement already satisfied: keras-TCN in /usr/local/lib/python3.6/dist-packages (2.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras-TCN) (1.14.6)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-TCN) (2.2.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-TCN) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-TCN) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-TCN) (1.0.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-TCN) (2.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-TCN) (1.0.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-TCN) (1.11.0)
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from itertools import zip_longest
def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    args = [iter(iterable)] * n
    return zip_longest(fillvalue=fillvalue, *args)

class ReutersGenerator():
    def __init__(self, max_seq_length=250, num_words=5000):
        self.tok = Tokenizer(num_words=num_words)
        self.max_seq_length = max_seq_length
        self.num_words = num_words
    
    def _gen_sents(self, fids):
        return (' '.join(sent) for fid in fids for sent in reuters.sents(fid))
    
    def fit(self, fid_startswith='train'):
        fids = (fid for fid in reuters.fileids() if fid.startswith(fid_startswith))
        self.tok.fit_on_texts(self._gen_sents(fids))
        return self

    def count(self, fid_startswith='train'):
        fids = (fid for fid in reuters.fileids() if fid.startswith(fid_startswith))
        return sum(1 for _ in self._gen_sents(fids))
    
    def inverse_transform(self, X):
        return self.tok.sequences_to_texts(X)
    
    def generate_pairs(self, fid_startswith='train', bs=32, 
                         max_seq_len=250, forever=True, shuffle=True):
        fids_in = np.array([fid for fid in reuters.fileids() if fid.startswith(fid_startswith)])
        index = np.arange(fids_in.shape[0])
        while True:
            np.random.shuffle(index)
            fids = fids_in[index]
            sents = self._gen_sents(fids)
            for batch in grouper(sents, bs):
                seqs = self.tok.texts_to_sequences_generator(text for text in batch if text)
                X = pad_sequences(list(seqs), self.max_seq_length)
                yield X, to_categorical(X, self.num_words)
            if not forever:
                break

# %%
reuters_gen = ReutersGenerator(
    num_words=MAX_NUM_WORDS, max_seq_length=MAX_SEQUENCE_LEN).fit()
n_train = reuters_gen.count('train')
#n_test = reuters_gen.count('test')

# %%
if not os.path.isfile("glove.6B.100d.txt"):
  # !wget "http://nlp.stanford.edu/data/glove.6B.zip"
  # !unzip "glove.6B.zip"

# get glove coeff matrix
embeddings_index = {}
with open("glove.6B.100d.txt", encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
print('Found %s word vectors.' % len(embeddings_index))

# prepare pre-learned embedding matrix
embdedding_dim = 100
word_index = reuters_gen.tok.word_index
num_words = min(MAX_NUM_WORDS, len(word_index)) + 1
embedding_matrix = np.zeros((num_words, embdedding_dim))
for word, i in word_index.items():
    if i > MAX_NUM_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# --2019-01-15 10:28:57--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2019-01-15 10:28:57--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  25.7MB/s    in 33s
#
# 2019-01-15 10:29:30 (25.2 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt
# Found 400000 word vectors.

# %%
kernel_size = 3
n_dilations = 8
n_hidden = 256
embedding_size = 100
dropout=0.4

input_layer = Input(shape=(MAX_SEQUENCE_LEN,))
encoder = None
if not USE_GLOVE:
  encoder = Embedding(MAX_NUM_WORDS, embedding_size)(input_layer)
else:
  encoder = Embedding(num_words, embdedding_dim, 
                      input_length=MAX_SEQUENCE_LEN, 
                      embeddings_initializer=Constant(embedding_matrix),
                      trainable=True)(input_layer)
encoder = TCN(return_sequences=True,
              kernel_size=kernel_size,
              dilations=[2**n for n in range(n_dilations)],
              nb_filters=n_hidden,
              nb_stacks=1,
              dropout_rate=dropout)(encoder)
latent = TCN(name='latent', return_sequences=False,
              kernel_size=kernel_size,
              dilations=[2**n for n in range(n_dilations)],
              nb_filters=100,
              nb_stacks=1,
              dropout_rate=dropout)(encoder)
decoder = RepeatVector(MAX_SEQUENCE_LEN)(latent)
decoder = TCN(name='dec', return_sequences=True,
              kernel_size=kernel_size,
              dilations=[2**n for n in range(n_dilations)],
              nb_filters=n_hidden,
              nb_stacks=1,
              dropout_rate=dropout)(decoder)
output_layer = TimeDistributed(Dense(MAX_NUM_WORDS, activation='softmax'))(decoder)
model = Model(input_layer, output_layer)
optimizer = optimizers.Adam(lr=0.002, clipnorm=0.4)
model.compile(optimizer=optimizer, metrics=['accuracy'], loss='categorical_crossentropy')
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 100)          0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 100, 100)     1000100     input_14[0][0]
# __________________________________________________________________________________________________
# tcn_initial_conv (Conv1D)       (None, 100, 256)     25856       embedding_14[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_1_tanh_s0 (Co (None, 100, 256)     196864      tcn_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 100, 256)     0           tcn_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# lambda_154 (Lambda)             (None, 100, 256)     0           activation_172[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_1_s0_0.40 (None, 100, 256)     0           lambda_154[0][0]
# __________________________________________________________________________________________________
# conv1d_153 (Conv1D)             (None, 100, 256)     65792       tcn_spatial_dropout1d_1_s0_0.4000
# __________________________________________________________________________________________________
# add_172 (Add)                   (None, 100, 256)     0           tcn_initial_conv[0][0]
#                                                                  conv1d_153[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_2_tanh_s0 (Co (None, 100, 256)     196864      add_172[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 100, 256)     0           tcn_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# lambda_155 (Lambda)             (None, 100, 256)     0           activation_173[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_2_s0_0.40 (None, 100, 256)     0           lambda_155[0][0]
# __________________________________________________________________________________________________
# conv1d_154 (Conv1D)             (None, 100, 256)     65792       tcn_spatial_dropout1d_2_s0_0.4000
# __________________________________________________________________________________________________
# add_173 (Add)                   (None, 100, 256)     0           add_172[0][0]
#                                                                  conv1d_154[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_4_tanh_s0 (Co (None, 100, 256)     196864      add_173[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 100, 256)     0           tcn_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# lambda_156 (Lambda)             (None, 100, 256)     0           activation_174[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_4_s0_0.40 (None, 100, 256)     0           lambda_156[0][0]
# __________________________________________________________________________________________________
# conv1d_155 (Conv1D)             (None, 100, 256)     65792       tcn_spatial_dropout1d_4_s0_0.4000
# __________________________________________________________________________________________________
# add_174 (Add)                   (None, 100, 256)     0           add_173[0][0]
#                                                                  conv1d_155[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_8_tanh_s0 (Co (None, 100, 256)     196864      add_174[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 100, 256)     0           tcn_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# lambda_157 (Lambda)             (None, 100, 256)     0           activation_175[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_8_s0_0.40 (None, 100, 256)     0           lambda_157[0][0]
# __________________________________________________________________________________________________
# conv1d_156 (Conv1D)             (None, 100, 256)     65792       tcn_spatial_dropout1d_8_s0_0.4000
# __________________________________________________________________________________________________
# add_175 (Add)                   (None, 100, 256)     0           add_174[0][0]
#                                                                  conv1d_156[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_16_tanh_s0 (C (None, 100, 256)     196864      add_175[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 100, 256)     0           tcn_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# lambda_158 (Lambda)             (None, 100, 256)     0           activation_176[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_16_s0_0.4 (None, 100, 256)     0           lambda_158[0][0]
# __________________________________________________________________________________________________
# conv1d_157 (Conv1D)             (None, 100, 256)     65792       tcn_spatial_dropout1d_16_s0_0.400
# __________________________________________________________________________________________________
# add_176 (Add)                   (None, 100, 256)     0           add_175[0][0]
#                                                                  conv1d_157[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_32_tanh_s0 (C (None, 100, 256)     196864      add_176[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 100, 256)     0           tcn_d_causal_conv_32_tanh_s0[0][0
# __________________________________________________________________________________________________
# lambda_159 (Lambda)             (None, 100, 256)     0           activation_177[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_32_s0_0.4 (None, 100, 256)     0           lambda_159[0][0]
# __________________________________________________________________________________________________
# conv1d_158 (Conv1D)             (None, 100, 256)     65792       tcn_spatial_dropout1d_32_s0_0.400
# __________________________________________________________________________________________________
# add_177 (Add)                   (None, 100, 256)     0           add_176[0][0]
#                                                                  conv1d_158[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_64_tanh_s0 (C (None, 100, 256)     196864      add_177[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 100, 256)     0           tcn_d_causal_conv_64_tanh_s0[0][0
# __________________________________________________________________________________________________
# lambda_160 (Lambda)             (None, 100, 256)     0           activation_178[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_64_s0_0.4 (None, 100, 256)     0           lambda_160[0][0]
# __________________________________________________________________________________________________
# conv1d_159 (Conv1D)             (None, 100, 256)     65792       tcn_spatial_dropout1d_64_s0_0.400
# __________________________________________________________________________________________________
# add_178 (Add)                   (None, 100, 256)     0           add_177[0][0]
#                                                                  conv1d_159[0][0]
# __________________________________________________________________________________________________
# tcn_d_causal_conv_128_tanh_s0 ( (None, 100, 256)     196864      add_178[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 100, 256)     0           tcn_d_causal_conv_128_tanh_s0[0][
# __________________________________________________________________________________________________
# lambda_161 (Lambda)             (None, 100, 256)     0           activation_179[0][0]
# __________________________________________________________________________________________________
# tcn_spatial_dropout1d_128_s0_0. (None, 100, 256)     0           lambda_161[0][0]
# __________________________________________________________________________________________________
# conv1d_160 (Conv1D)             (None, 100, 256)     65792       tcn_spatial_dropout1d_128_s0_0.40
# __________________________________________________________________________________________________
# add_180 (Add)                   (None, 100, 256)     0           conv1d_153[0][0]
#                                                                  conv1d_154[0][0]
#                                                                  conv1d_155[0][0]
#                                                                  conv1d_156[0][0]
#                                                                  conv1d_157[0][0]
#                                                                  conv1d_158[0][0]
#                                                                  conv1d_159[0][0]
#                                                                  conv1d_160[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 100, 256)     0           add_180[0][0]
# __________________________________________________________________________________________________
# latent_initial_conv (Conv1D)    (None, 100, 100)     25700       activation_180[0][0]
# __________________________________________________________________________________________________
# latent_d_causal_conv_1_tanh_s0  (None, 100, 100)     30100       latent_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 100, 100)     0           latent_d_causal_conv_1_tanh_s0[0]
# __________________________________________________________________________________________________
# lambda_162 (Lambda)             (None, 100, 100)     0           activation_181[0][0]
# __________________________________________________________________________________________________
# latent_spatial_dropout1d_1_s0_0 (None, 100, 100)     0           lambda_162[0][0]
# __________________________________________________________________________________________________
# conv1d_161 (Conv1D)             (None, 100, 100)     10100       latent_spatial_dropout1d_1_s0_0.4
# __________________________________________________________________________________________________
# add_181 (Add)                   (None, 100, 100)     0           latent_initial_conv[0][0]
#                                                                  conv1d_161[0][0]
# __________________________________________________________________________________________________
# latent_d_causal_conv_2_tanh_s0  (None, 100, 100)     30100       add_181[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 100, 100)     0           latent_d_causal_conv_2_tanh_s0[0]
# __________________________________________________________________________________________________
# lambda_163 (Lambda)             (None, 100, 100)     0           activation_182[0][0]
# __________________________________________________________________________________________________
# latent_spatial_dropout1d_2_s0_0 (None, 100, 100)     0           lambda_163[0][0]
# __________________________________________________________________________________________________
# conv1d_162 (Conv1D)             (None, 100, 100)     10100       latent_spatial_dropout1d_2_s0_0.4
# __________________________________________________________________________________________________
# add_182 (Add)                   (None, 100, 100)     0           add_181[0][0]
#                                                                  conv1d_162[0][0]
# __________________________________________________________________________________________________
# latent_d_causal_conv_4_tanh_s0  (None, 100, 100)     30100       add_182[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 100, 100)     0           latent_d_causal_conv_4_tanh_s0[0]
# __________________________________________________________________________________________________
# lambda_164 (Lambda)             (None, 100, 100)     0           activation_183[0][0]
# __________________________________________________________________________________________________
# latent_spatial_dropout1d_4_s0_0 (None, 100, 100)     0           lambda_164[0][0]
# __________________________________________________________________________________________________
# conv1d_163 (Conv1D)             (None, 100, 100)     10100       latent_spatial_dropout1d_4_s0_0.4
# __________________________________________________________________________________________________
# add_183 (Add)                   (None, 100, 100)     0           add_182[0][0]
#                                                                  conv1d_163[0][0]
# __________________________________________________________________________________________________
# latent_d_causal_conv_8_tanh_s0  (None, 100, 100)     30100       add_183[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 100, 100)     0           latent_d_causal_conv_8_tanh_s0[0]
# __________________________________________________________________________________________________
# lambda_165 (Lambda)             (None, 100, 100)     0           activation_184[0][0]
# __________________________________________________________________________________________________
# latent_spatial_dropout1d_8_s0_0 (None, 100, 100)     0           lambda_165[0][0]
# __________________________________________________________________________________________________
# conv1d_164 (Conv1D)             (None, 100, 100)     10100       latent_spatial_dropout1d_8_s0_0.4
# __________________________________________________________________________________________________
# add_184 (Add)                   (None, 100, 100)     0           add_183[0][0]
#                                                                  conv1d_164[0][0]
# __________________________________________________________________________________________________
# latent_d_causal_conv_16_tanh_s0 (None, 100, 100)     30100       add_184[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 100, 100)     0           latent_d_causal_conv_16_tanh_s0[0
# __________________________________________________________________________________________________
# lambda_166 (Lambda)             (None, 100, 100)     0           activation_185[0][0]
# __________________________________________________________________________________________________
# latent_spatial_dropout1d_16_s0_ (None, 100, 100)     0           lambda_166[0][0]
# __________________________________________________________________________________________________
# conv1d_165 (Conv1D)             (None, 100, 100)     10100       latent_spatial_dropout1d_16_s0_0.
# __________________________________________________________________________________________________
# add_185 (Add)                   (None, 100, 100)     0           add_184[0][0]
#                                                                  conv1d_165[0][0]
# __________________________________________________________________________________________________
# latent_d_causal_conv_32_tanh_s0 (None, 100, 100)     30100       add_185[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 100, 100)     0           latent_d_causal_conv_32_tanh_s0[0
# __________________________________________________________________________________________________
# lambda_167 (Lambda)             (None, 100, 100)     0           activation_186[0][0]
# __________________________________________________________________________________________________
# latent_spatial_dropout1d_32_s0_ (None, 100, 100)     0           lambda_167[0][0]
# __________________________________________________________________________________________________
# conv1d_166 (Conv1D)             (None, 100, 100)     10100       latent_spatial_dropout1d_32_s0_0.
# __________________________________________________________________________________________________
# add_186 (Add)                   (None, 100, 100)     0           add_185[0][0]
#                                                                  conv1d_166[0][0]
# __________________________________________________________________________________________________
# latent_d_causal_conv_64_tanh_s0 (None, 100, 100)     30100       add_186[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 100, 100)     0           latent_d_causal_conv_64_tanh_s0[0
# __________________________________________________________________________________________________
# lambda_168 (Lambda)             (None, 100, 100)     0           activation_187[0][0]
# __________________________________________________________________________________________________
# latent_spatial_dropout1d_64_s0_ (None, 100, 100)     0           lambda_168[0][0]
# __________________________________________________________________________________________________
# conv1d_167 (Conv1D)             (None, 100, 100)     10100       latent_spatial_dropout1d_64_s0_0.
# __________________________________________________________________________________________________
# add_187 (Add)                   (None, 100, 100)     0           add_186[0][0]
#                                                                  conv1d_167[0][0]
# __________________________________________________________________________________________________
# latent_d_causal_conv_128_tanh_s (None, 100, 100)     30100       add_187[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 100, 100)     0           latent_d_causal_conv_128_tanh_s0[
# __________________________________________________________________________________________________
# lambda_169 (Lambda)             (None, 100, 100)     0           activation_188[0][0]
# __________________________________________________________________________________________________
# latent_spatial_dropout1d_128_s0 (None, 100, 100)     0           lambda_169[0][0]
# __________________________________________________________________________________________________
# conv1d_168 (Conv1D)             (None, 100, 100)     10100       latent_spatial_dropout1d_128_s0_0
# __________________________________________________________________________________________________
# add_189 (Add)                   (None, 100, 100)     0           conv1d_161[0][0]
#                                                                  conv1d_162[0][0]
#                                                                  conv1d_163[0][0]
#                                                                  conv1d_164[0][0]
#                                                                  conv1d_165[0][0]
#                                                                  conv1d_166[0][0]
#                                                                  conv1d_167[0][0]
#                                                                  conv1d_168[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 100, 100)     0           add_189[0][0]
# __________________________________________________________________________________________________
# lambda_170 (Lambda)             (None, 100)          0           activation_189[0][0]
# __________________________________________________________________________________________________
# repeat_vector_3 (RepeatVector)  (None, 100, 100)     0           lambda_170[0][0]
# __________________________________________________________________________________________________
# dec_initial_conv (Conv1D)       (None, 100, 256)     25856       repeat_vector_3[0][0]
# __________________________________________________________________________________________________
# dec_d_causal_conv_1_tanh_s0 (Co (None, 100, 256)     196864      dec_initial_conv[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 100, 256)     0           dec_d_causal_conv_1_tanh_s0[0][0]
# __________________________________________________________________________________________________
# lambda_171 (Lambda)             (None, 100, 256)     0           activation_190[0][0]
# __________________________________________________________________________________________________
# dec_spatial_dropout1d_1_s0_0.40 (None, 100, 256)     0           lambda_171[0][0]
# __________________________________________________________________________________________________
# conv1d_169 (Conv1D)             (None, 100, 256)     65792       dec_spatial_dropout1d_1_s0_0.4000
# __________________________________________________________________________________________________
# add_190 (Add)                   (None, 100, 256)     0           dec_initial_conv[0][0]
#                                                                  conv1d_169[0][0]
# __________________________________________________________________________________________________
# dec_d_causal_conv_2_tanh_s0 (Co (None, 100, 256)     196864      add_190[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 100, 256)     0           dec_d_causal_conv_2_tanh_s0[0][0]
# __________________________________________________________________________________________________
# lambda_172 (Lambda)             (None, 100, 256)     0           activation_191[0][0]
# __________________________________________________________________________________________________
# dec_spatial_dropout1d_2_s0_0.40 (None, 100, 256)     0           lambda_172[0][0]
# __________________________________________________________________________________________________
# conv1d_170 (Conv1D)             (None, 100, 256)     65792       dec_spatial_dropout1d_2_s0_0.4000
# __________________________________________________________________________________________________
# add_191 (Add)                   (None, 100, 256)     0           add_190[0][0]
#                                                                  conv1d_170[0][0]
# __________________________________________________________________________________________________
# dec_d_causal_conv_4_tanh_s0 (Co (None, 100, 256)     196864      add_191[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 100, 256)     0           dec_d_causal_conv_4_tanh_s0[0][0]
# __________________________________________________________________________________________________
# lambda_173 (Lambda)             (None, 100, 256)     0           activation_192[0][0]
# __________________________________________________________________________________________________
# dec_spatial_dropout1d_4_s0_0.40 (None, 100, 256)     0           lambda_173[0][0]
# __________________________________________________________________________________________________
# conv1d_171 (Conv1D)             (None, 100, 256)     65792       dec_spatial_dropout1d_4_s0_0.4000
# __________________________________________________________________________________________________
# add_192 (Add)                   (None, 100, 256)     0           add_191[0][0]
#                                                                  conv1d_171[0][0]
# __________________________________________________________________________________________________
# dec_d_causal_conv_8_tanh_s0 (Co (None, 100, 256)     196864      add_192[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 100, 256)     0           dec_d_causal_conv_8_tanh_s0[0][0]
# __________________________________________________________________________________________________
# lambda_174 (Lambda)             (None, 100, 256)     0           activation_193[0][0]
# __________________________________________________________________________________________________
# dec_spatial_dropout1d_8_s0_0.40 (None, 100, 256)     0           lambda_174[0][0]
# __________________________________________________________________________________________________
# conv1d_172 (Conv1D)             (None, 100, 256)     65792       dec_spatial_dropout1d_8_s0_0.4000
# __________________________________________________________________________________________________
# add_193 (Add)                   (None, 100, 256)     0           add_192[0][0]
#                                                                  conv1d_172[0][0]
# __________________________________________________________________________________________________
# dec_d_causal_conv_16_tanh_s0 (C (None, 100, 256)     196864      add_193[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 100, 256)     0           dec_d_causal_conv_16_tanh_s0[0][0
# __________________________________________________________________________________________________
# lambda_175 (Lambda)             (None, 100, 256)     0           activation_194[0][0]
# __________________________________________________________________________________________________
# dec_spatial_dropout1d_16_s0_0.4 (None, 100, 256)     0           lambda_175[0][0]
# __________________________________________________________________________________________________
# conv1d_173 (Conv1D)             (None, 100, 256)     65792       dec_spatial_dropout1d_16_s0_0.400
# __________________________________________________________________________________________________
# add_194 (Add)                   (None, 100, 256)     0           add_193[0][0]
#                                                                  conv1d_173[0][0]
# __________________________________________________________________________________________________
# dec_d_causal_conv_32_tanh_s0 (C (None, 100, 256)     196864      add_194[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 100, 256)     0           dec_d_causal_conv_32_tanh_s0[0][0
# __________________________________________________________________________________________________
# lambda_176 (Lambda)             (None, 100, 256)     0           activation_195[0][0]
# __________________________________________________________________________________________________
# dec_spatial_dropout1d_32_s0_0.4 (None, 100, 256)     0           lambda_176[0][0]
# __________________________________________________________________________________________________
# conv1d_174 (Conv1D)             (None, 100, 256)     65792       dec_spatial_dropout1d_32_s0_0.400
# __________________________________________________________________________________________________
# add_195 (Add)                   (None, 100, 256)     0           add_194[0][0]
#                                                                  conv1d_174[0][0]
# __________________________________________________________________________________________________
# dec_d_causal_conv_64_tanh_s0 (C (None, 100, 256)     196864      add_195[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 100, 256)     0           dec_d_causal_conv_64_tanh_s0[0][0
# __________________________________________________________________________________________________
# lambda_177 (Lambda)             (None, 100, 256)     0           activation_196[0][0]
# __________________________________________________________________________________________________
# dec_spatial_dropout1d_64_s0_0.4 (None, 100, 256)     0           lambda_177[0][0]
# __________________________________________________________________________________________________
# conv1d_175 (Conv1D)             (None, 100, 256)     65792       dec_spatial_dropout1d_64_s0_0.400
# __________________________________________________________________________________________________
# add_196 (Add)                   (None, 100, 256)     0           add_195[0][0]
#                                                                  conv1d_175[0][0]
# __________________________________________________________________________________________________
# dec_d_causal_conv_128_tanh_s0 ( (None, 100, 256)     196864      add_196[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 100, 256)     0           dec_d_causal_conv_128_tanh_s0[0][
# __________________________________________________________________________________________________
# lambda_178 (Lambda)             (None, 100, 256)     0           activation_197[0][0]
# __________________________________________________________________________________________________
# dec_spatial_dropout1d_128_s0_0. (None, 100, 256)     0           lambda_178[0][0]
# __________________________________________________________________________________________________
# conv1d_176 (Conv1D)             (None, 100, 256)     65792       dec_spatial_dropout1d_128_s0_0.40
# __________________________________________________________________________________________________
# add_198 (Add)                   (None, 100, 256)     0           conv1d_169[0][0]
#                                                                  conv1d_170[0][0]
#                                                                  conv1d_171[0][0]
#                                                                  conv1d_172[0][0]
#                                                                  conv1d_173[0][0]
#                                                                  conv1d_174[0][0]
#                                                                  conv1d_175[0][0]
#                                                                  conv1d_176[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 100, 256)     0           add_198[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 100, 10000)   2570000     activation_198[0][0]
# ==================================================================================================
# Total params: 8,171,608
# Trainable params: 8,171,608
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
basename = 'seq2seq-TCN-model-small-nolatent'
outfname = os.path.join(
    OUTPUTDIR,
    basename + '-ep{epoch:02d}.hdf5')
cp = ModelCheckpoint(
    outfname,
    save_best_only=False,
    save_weights_only=False)

# %%
TRAIN_MODEL = True
BATCH_SIZE = 32
EPOCHS = 20

if TRAIN_MODEL:
  history = model.fit_generator(reuters_gen.generate_pairs('train', bs=BATCH_SIZE),
      #validation_data=reuters_gen.generate_pairs('test', bs=BATCH_SIZE),
      steps_per_epoch=n_train//BATCH_SIZE,
      #validation_steps=n_test//BATCH_SIZE,
      epochs=EPOCHS, shuffle=True, callbacks=[cp])
else:
  list_of_files = glob.glob(os.path.join(OUTPUTDIR, basename + '*.hdf5'))
  list_of_files = sorted(list_of_files, key=os.path.getctime)
  assert(len(list_of_files) > 0)
  model = load_model(list_of_files[-1])
  print('Loaded model from \'%s\'' % list_of_files[-1])
# Out:
# Epoch 1/20
#  133/1258 [==>...........................] - ETA: 6:15 - loss: 1.3862 - acc: 0.7679

# %%
X_test, X_test_hat = next(reuters_gen.generate_pairs('test'))

# %%
reuters_gen.inverse_transform(np.argmax(model.predict(X_test[:10], verbose=1), axis=2))
# Out:
# 10/10 [==============================] - 0s 8ms/step
# ['s s in in in in in in in in in in in in in the in the rose rose to to to pct pct pct pct in in in in in pct pct pct in in in pct pct pct pct pct in the the the figures show',
#  'exports rose rose rose to to billion billion billion in in in in in to billion billion in in in the the of 1 billion billion',
#  'the february discount fell rose rose to marks marks 1 billion billion',
#  'the the of rose to to mln mln mln billion in in in the the and and and mln mln mln mln mln mln mln in in 1986',
#  'in in pct pct pct pct pct pct pct pct pct pct pct the pct pct pct pct pct pct pct pct pct in the the in to to to 2 pct pct pct pct pct pct pct pct pct pct pct pct pct pct the bureau show',
#  'exports exports rose rose to billion billion billion billion pct in in and and and billion billion billion billion billion pct in january',
#  'bank bank said bank s had rate to to to 0 billion pct',
#  'bank bank said bank s had rate to to to 0 billion pct',
#  'the said the the the the the the the the the said said said said the to to to the the the the to to pct pct the the the the the the the the rates',
#  'the the the the the the to to mln mln mln mln mln mln mln mln to to mln mln mln mln mln in the the the the the to to mln and the the the to mln mln mln in 1986']

# %%
reuters_gen.inverse_transform(X_test[:10])
# Out:
# ['south african m 3 april growth revised upward south african year on year broadly defined m 3 money supply growth was revised upward to 10 37 pct for april from a preliminary 10 08 pct but was down from a revised 10 69 pct in march reserve bank figures show',
#  "m 3 rose to a revised 82 38 billion rand in april from a preliminary 82 17 billion and march ' s revised 81 39 billion",
#  'in april last year m 3 stood at 74 64 billion rand',
#  'preliminary figures for may show m 3 at 83 24 billion rand for a year on year rise of 10 97 pct from 75 01 billion in may 1986',
#  'april m rose a year on year 15 12 pct to 14 22 billion rand after rising 14 72 pct to 13 97 billion in march while m1 rose 24 49 pct to 27 92 billion after a 20 69 pct increase to 26 97 billion the figures showed',
#  'm 2 rose 8 28 pct to 58 71 billion in april after rising 6 47 pct to 57 52 billion in march',
#  'bank of france says it leaves intervention rate unchanged at 7 1 2 pct',
#  'bank of france says it leaves intervention rate unchanged at 7 1 2 pct',
#  "bangladesh ' s trade gap to widen in 1987 88 bangladesh ' s trade gap is expected to widen in fiscal 1987 88 beginning on july 1 after the government restrictions on some imports including cars",
#  "the country has set its export target for the year at 1 1 billion u s dlrs against imports of 1 805 billion dlrs compared with 1986 7 ' s one billion dlrs of export earnings and 1 113 billion dlrs of imports"]
